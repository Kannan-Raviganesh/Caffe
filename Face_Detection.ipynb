# %%
import cv2
from PIL import Image
import numpy as np
import time
import sys
import os

# %%
model = "res10_300x300_ssd_iter_140000.caffemodel"
config = "deploy.prototxt.txt"
net = cv2.dnn.readNetFromCaffe(config, model)

labels = ["Face"]
colors = np.random.uniform(0, 255, size=(len(labels), 3))

def Face_Detection(img):
  face_extracts = [] #Extracted Faces
  accuracy=[] 
  h, w = img.shape[:2]
  blob = cv2.dnn.blobFromImage(cv2.resize(img,(600,600)),2.0,(600,600), (104.0,117.0,123.0))
  required_size=(160, 160)
  net.setInput(blob)
  faces = net.forward()
  for i in range(0, faces.shape[2]):
    box = faces[0, 0, i, 3:7] * np.array([w, h, w, h])
    (startX, startY, endX, endY) = box.astype("int")
    confidence = faces[0, 0, i, 2]
    if (confidence > 0.5):
      startX, startY = abs(startX), abs(startY)
      frame = img[startY:endY, startX:endX]
      image = Image.fromarray(frame)
      image = image.resize(required_size)
      face_array = np.asarray(image)
      face_extracts.append(face_array)
      accuracy.append(confidence)

  Value = {"Extracted Face": face_extracts, "Accuracy": accuracy}
 
  print(Value)
  return image

# %%
img=cv2.imread("Thor.jpg")
Face_Detection(img)
# Out:
# {'Extracted Face': [array([[[166, 124, 131],
#         [156, 115, 121],
#         [139,  98, 102],
#         ...,
#         [215, 145, 151],
#         [228, 157, 163],
#         [230, 158, 164]],
#
#        [[128,  86,  94],
#         [134,  92,  99],
#         [136,  94,  99],
#         ...,
#         [209, 139, 145],
#         [155,  84,  91],
#         [117,  47,  53]],
#
#        [[164, 122, 129],
#         [155, 114, 120],
#         [147, 105, 110],
#         ...,
#         [112,  46,  50],
#         [110,  41,  47],
#         [103,  32,  39]],
#
#        ...,
#
#        [[232, 181, 185],
#         [231, 179, 183],
#         [229, 178, 182],
#         ...,
#         [165, 102, 109],
#         [153,  94,  98],
#         [143,  86,  89]],
#
#        [[234, 183, 187],
#         [231, 180, 184],
#         [227, 176, 180],
#         ...,
#         [178, 116, 122],
#         [155,  95, 100],
#         [131,  75,  78]],
#
#        [[237, 186, 190],
#         [232, 181, 185],
#         [227, 176, 180],
#         ...,
#         [182, 120, 124],
#         [151,  92,  95],
#         [118,  62,  65]]], dtype=uint8)], 'Accuracy': [0.9993266]}
# <PIL.Image.Image image mode=RGB size=160x160 at 0x25AD1CA4DA0>
